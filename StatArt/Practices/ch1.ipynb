# %% [markdown]
# # Bài 1.1
# a) xem xét dữ liệu bệnh nhân cá nhân từ 51 thử nghiệm ngẫu nhiên (77.000 người tham gia) dùng aspirin hàng ngày so với không dùng aspirin hoặc các thuốc chống kết tập tiểu cầu khác, 5 năm
#
# b) 562, 644, 15%
#
# c) kết luận cho tổng thể  làm giảm nguy cơ

# %% [markdown]
# # Bài 1.3
# a) 4,854
#
# b) ![Screenshot from 2023-05-19 11-37-37.png](attachment:7a969351-57c6-46d5-97b5-8af86388cd04.png)
#
# C) 61.2% vs 64.3%

# %% [markdown]
# # Bài 1.4
# a) ![Screenshot from 2023-05-19 11-53-42.png](attachment:d9a9e13a-0faf-43b9-ad78-095867d2dcf7.png)
#
# b) 51.6% vs 61.2%

# %% [markdown]
# # Bài 1.5
# a) 575
#
# b) 40 - 36.9%

# %% [markdown]
# # Bài 1.7
# a) Mẫu: 170 sinh viên
#
# b) tổng thể: toàn bộ sinh viên tại trường
#
# c) 45%

# %% [markdown]
# # Bài 1.9
# a) đối tượng: giảng viên
#
# b) mẫu: giảng viên được phỏng vấn
#
# c) tổng thể: toàn bộ giảng viên

# %% [markdown]
# # Bài 1.10
# a) mẫu: những ngừoi được hỏi
#     tổng thể: toàn bộ ngừoi dân tại các nước
#
# b) đây là thống kê vì được tính từ 1 mẫu

# %% [markdown]
# # Bài 1.11
# a) mô tả vì khảo sát toàn bộ sv mới ra trường
#
# b) tham số vì đo lường trên tổng thể

# %% [markdown]
# # Bài 1.12
# a) 1970-2000, trung bình 11.6
#
# b) 11.25 đến 11.95
#
# c) tỉ lệ lạm phát trung bình của Ai Cập cuối tk 20
#
# d) thống kê vì rút ra từ mẫu

# %% [markdown]
# # Bài 1.16
# a) 5 lần vì càng tung nhiều thì càng gần với 50/50
#
# b) vì theo a), tung càng nhiều thì kết quả càng ít khác biệt
#
# c) ![Sampling Distribution.png](attachment:8d24912d-ede9-4ca9-96fc-6b24d12ef12f.png)
#
#      - Nhỏ nhất 0%, lớn nhất 100%
#      - 60% xảy ra nhiều nhất

# %% [markdown]
# # Bài 1.17
# a) nghĩa là tỉ lệ thực tế đâu đó trong khoảng 27% - 31%
#
# b) Không vì chỉ Pulse Consultant thỏa mãn
#
# c) ![Sampling Distribution.png](attachment:d9e183df-805b-4b85-b6b9-e814a5e55a60.png)
